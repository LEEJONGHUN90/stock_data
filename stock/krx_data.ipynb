# %% [markdown]
# # 한국거래소 상장 주식 데이터 분석

# %% [markdown]
# ## FinanceDataReader
#
# ### 한국 주식가격,미국주식 가격,지수,환율,암호화페 가격, 종목 리스팅 등 금융 데이터 수집 라이브러리
#
# #### !pip install -U finance-datareader

# %% [markdown]
# !pip install -U finance-datareader
#
# !pip install seaborn

# %%
import pandas as pd
import FinanceDataReader as fdr

# %%
#StockListing으로  거래소마다 해당하는 주식 종목의 코드와 각종 정보를 가져와 줍니다.
#KRX, KOSPI, KOSDAQ, KONEX, NYSE, NASDAQ, AMEX, SP500 등
df_krx=fdr.StockListing("KRX")

# %%
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월                박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
#to_csv로 DataFrame을  csv파일로 저장

df_krx.to_csv("krx.csv",index=False)

# %%
# csv파일을 dataframe으로 읽어보기

pd.read_csv("krx.csv")
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7890  000545   KOSPI            흥국화재우                       NaN
# 7891  003280   KOSPI             흥아해운                    해상 운송업
# 7892  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7893  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7894  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...

# %%
#데이터분석 pandas, 시각화위해 seaborn
import pandas as pd
import seaborn as sns

# %%
#주의사항 symbol은 숫자형태지만 앞에 0이 있어 문자임  혹시나 0이누락되면 숫자로 나올수있으니
df=pd.read_csv("krx.csv",dtype={"Symbol":object})
df.shape
# Out:
# (7895, 10)

# %% [markdown]
# ## 상장회사의 데이터를 통한 여러 데이터 분석
#  {'회사명':'Name', '종목코드':'Symbol', '업종':'Sector', '주요제품':'Industry',
#                             '상장일':'ListingDate', '결산월':'SettleMonth',  '대표자명':'Representative',
#                             '홈페이지':'HomePage', '지역':'Region', }

# %%
#데이터를 head를 통해 위에서5개의 데이터 뽑아옴.
df.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월                박대현         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
# tail 을 통해 끝에서 5개 데이터 뽑아옴
df.tail()
# Out:
#       Symbol  Market             Name                    Sector  \
# 7890  000545   KOSPI            흥국화재우                       NaN
# 7891  003280   KOSPI             흥아해운                    해상 운송업
# 7892  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7893  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7894  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 7890                             NaN         NaN         NaN
# 7891                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 7892                       설계 및 감리용역  2000-02-03         12월
# 7893                             NaN         NaN         NaN
# 7894  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#             Representative                HomePage Region
# 7890                   NaN                     NaN    NaN
# 7891                   이환구  http://www.heung-a.com  서울특별시
# ...

# %%
#sample을 사용하면 랜덤하게()안의 갯수만큼 가져옴.

df.sample(5)
# Out:
#       Symbol  Market             Name                    Sector  \
# 3872  52H939   KOSPI  미래H939KOSPI200콜                       NaN
# 7664  009540   KOSPI           한국조선해양               선박 및 보트 건조업
# 7087  57H287   KOSPI  한국H287KOSPI200콜                       NaN
# 5240  258610  KOSDAQ           이더블유케이  구조용 금속제품, 탱크 및 증기발생기 제조업
# 350   58GQ08   KOSPI      KBGQ08삼성전자콜                       NaN
#
#                                       Industry ListingDate SettleMonth  \
# 3872                                       NaN         NaN         NaN
# 7664  선박,해양구조물,엔진,펌프 전동기,중전기,중장비 제조/자동창고,물류시스템  1999-08-24         12월
# 7087                                       NaN         NaN         NaN
# 5240                      지열발전설비(열수기화기, 응축기 등)  2017-08-22         12월
# 350                                        NaN         NaN         NaN
#
#      Representative                  HomePage Region
# 3872            NaN                       NaN    NaN
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7895, step=1)

# %%
df.columns
# Out:
# Index(['Symbol', 'Market', 'Name', 'Sector', 'Industry', 'ListingDate',
#        'SettleMonth', 'Representative', 'HomePage', 'Region'],
#       dtype='object')

# %%
#값만 보기
df.values
# Out:
# array([['060310', 'KOSDAQ', '3S', ..., '김세완', 'http://www.3sref.com',
#         '서울특별시'],
#        ['095570', 'KOSPI', 'AJ네트웍스', ..., '박대현',
#         'http://www.ajnet.co.kr', '서울특별시'],
#        ['006840', 'KOSPI', 'AK홀딩스', ..., '채형석, 이석주(각자 대표이사)',
#         'http://www.aekyunggroup.co.kr', '서울특별시'],
#        ...,
#        ['037440', 'KOSDAQ', '희림', ..., '정영균, 이목운, 허철호 (각자대표)',
#         'http://www.heerim.com', '서울특별시'],
#        ['419890', 'KOSPI', '히어로즈 단기채권ESG액티브', ..., nan, nan, nan],
#        ['238490', 'KOSDAQ', '힘스', ..., '김주환', 'http://www.hims.co.kr',
#         '인천광역시']], dtype=object)

# %%
#이름만 뽑아봄
df["Name"]
# Out:
# 0                    3S
# 1                AJ네트웍스
# 2                 AK홀딩스
# 3                APS홀딩스
# 4                 AP시스템
#              ...
# 7890              흥국화재우
# 7891               흥아해운
# 7892                 희림
# 7893    히어로즈 단기채권ESG액티브
# 7894                 힘스
# Name: Name, Length: 7895, dtype: object

# %%
#loc는 위치(loacte)를 의미
#첫번째 행에 있는 종목 뽑아봄
df.loc[0]
# Out:
# Symbol                          060310
# Market                          KOSDAQ
# Name                                3S
# Sector                        전자부품 제조업
# Industry                   반도체 웨이퍼 캐리어
# ListingDate                 2002-04-23
# SettleMonth                        03월
# Representative                     김세완
# HomePage          http://www.3sref.com
# Region                           서울특별시
# Name: 0, dtype: object

# %%
# 이번엔 심볼만 데이터를 뽑아봄.
df["Symbol"]
# Out:
# 0       060310
# 1       095570
# 2       006840
# 3       054620
# 4       265520
#          ...
# 7890    000545
# 7891    003280
# 7892    037440
# 7893    419890
# 7894    238490
# Name: Symbol, Length: 7895, dtype: object

# %%
# 심볼과 이름만 뽑아봄.
#여러 칼럼을 지정할 때는 리스트 형태로 묶어야함.
# 2차원 행렬은 대괄호가[]2개가 있음
df[["Symbol","Name"]]
# Out:
#       Symbol             Name
# 0     060310               3S
# 1     095570           AJ네트웍스
# 2     006840            AK홀딩스
# 3     054620           APS홀딩스
# 4     265520            AP시스템
# ...      ...              ...
# 7890  000545            흥국화재우
# 7891  003280             흥아해운
# 7892  037440               희림
# 7893  419890  히어로즈 단기채권ESG액티브
# 7894  238490               힘스
#
# [7895 rows x 2 columns]

# %%
# 이번엔 여러개의 행을 가져옴 0번째와 1번째
df.loc[[0,1]]
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
#
#   SettleMonth Representative                HomePage Region
# 0         03월            김세완    http://www.3sref.com  서울특별시
# 1         12월            박대현  http://www.ajnet.co.kr  서울특별시

# %%
#여러개의 행과 여러개의 컬럼 가져오기

df.loc[[0,1],["Name","Symbol"]]
# Out:
#      Name  Symbol
# 0      3S  060310
# 1  AJ네트웍스  095570

# %%
# name에서 주식 삼성전자의 데이터만 뽑아내봄.
df[df["Name"]=="삼성전자"]
# Out:
#       Symbol Market  Name          Sector  \
# 4139  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 4139  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative              HomePage Region
# 4139         12월            한종희  http://www.sec.co.kr    경기도

# %% [markdown]
# # 1. 지역별 상장회사 데이터 분석

# %%
# 먼저 지역별로 데이터를 뽑아내봄.
df["Region"]
# Out:
# 0       서울특별시
# 1       서울특별시
# 2       서울특별시
# 3         경기도
# 4         경기도
#         ...
# 7890      NaN
# 7891    서울특별시
# 7892    서울특별시
# 7893      NaN
# 7894    인천광역시
# Name: Region, Length: 7895, dtype: object

# %%
# 서울특별시에 위치한 주식회사 뽑아봄.
df["Region"]=="서울특별시"
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7890    False
# 7891     True
# 7892     True
# 7893    False
# 7894    False
# Name: Region, Length: 7895, dtype: bool

# %%
df[df["Region"]=="서울특별시"]
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S                  전자부품 제조업
# 1     095570   KOSPI  AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI   AK홀딩스                    기타 금융업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 50    027410   KOSPI     BGF                    기타 금융업
# ...      ...     ...     ...                       ...
# 7884  069260   KOSPI     휴켐스               기타 화학제품 제조업
# 7887  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 7888  000540   KOSPI    흥국화재                       보험업
# 7891  003280   KOSPI    흥아해운                    해상 운송업
# 7892  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
#
#                        Industry ListingDate SettleMonth        Representative  \
# 0                   반도체 웨이퍼 캐리어  2002-04-23         03월                   김세완
# 1           렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월                   박대현
# ...

# %%
#일단 위에서 서울특별시에 있는 회사만 뽑아냄
#그 다음 서울특별시안에서 코스피회사만 뽑아내보자


#우선 코스피 회사만 뽑아봄.
df[df["Market"]=="KOSPI"]
# Out:
#       Symbol Market               Name           Sector             Industry  \
# 1     095570  KOSPI             AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)
# 2     006840  KOSPI              AK홀딩스           기타 금융업                 지주사업
# 6     152100  KOSPI        ARIRANG 200              NaN                  NaN
# 7     295820  KOSPI    ARIRANG 200동일가중              NaN                  NaN
# 8     253150  KOSPI  ARIRANG 200선물레버리지              NaN                  NaN
# ...      ...    ...                ...              ...                  ...
# 7888  000540  KOSPI               흥국화재              보험업                 손해보험
# 7889  000547  KOSPI            흥국화재2우B              NaN                  NaN
# 7890  000545  KOSPI              흥국화재우              NaN                  NaN
# 7891  003280  KOSPI               흥아해운           해상 운송업       외항화물운송업(케미컬탱커)
# 7893  419890  KOSPI    히어로즈 단기채권ESG액티브              NaN                  NaN
#
# ...

# %%
#and >>>> &
#or>>>>> |

#연산자 우선순위가 있음 그래서 괄호로 묶어줘야함
(df["Region"]=="서울특별시") & (df["Market"]=="KOSPI")
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7890    False
# 7891     True
# 7892    False
# 7893    False
# 7894    False
# Length: 7895, dtype: bool

# %%
#한번더 df묶어줌
df[(df["Region"]=="서울특별시") & (df["Market"]=="KOSPI")]
# Out:
#       Symbol Market    Name           Sector  \
# 1     095570  KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업
# 2     006840  KOSPI   AK홀딩스           기타 금융업
# 50    027410  KOSPI     BGF           기타 금융업
# 51    282330  KOSPI  BGF리테일           종합 소매업
# 54    001460  KOSPI     BYC         봉제의복 제조업
# ...      ...    ...     ...              ...
# 7876  079980  KOSPI     휴비스         화학섬유 제조업
# 7879  005010  KOSPI     휴스틸        1차 철강 제조업
# 7884  069260  KOSPI     휴켐스      기타 화학제품 제조업
# 7888  000540  KOSPI    흥국화재              보험업
# 7891  003280  KOSPI    흥아해운           해상 운송업
#
#                                            Industry ListingDate SettleMonth  \
# 1                               렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                                              지주사업  1999-08-11         12월
# 50                                             지주회사  2014-05-19         12월
# 51                                          체인화 편의점  2017-12-08         12월
# ...

# %%
# 이번엔 ListingDate(상장일)을 통해 년도별만 뽑아내고싶어서
# 년도별로 파생변수 새로 생성함

#pd.to_datetime을 통해 데이터의 타입을 변환함.

df["ListingDate"]
# Out:
# 0       2002-04-23
# 1       2015-08-21
# 2       1999-08-11
# 3       2001-12-04
# 4       2017-04-07
#            ...
# 7890           NaN
# 7891    1976-06-29
# 7892    2000-02-03
# 7893           NaN
# 7894    2017-07-20
# Name: ListingDate, Length: 7895, dtype: object

# %%
pd.to_datetime(df["ListingDate"])
# Out:
# 0      2002-04-23
# 1      2015-08-21
# 2      1999-08-11
# 3      2001-12-04
# 4      2017-04-07
#           ...
# 7890          NaT
# 7891   1976-06-29
# 7892   2000-02-03
# 7893          NaT
# 7894   2017-07-20
# Name: ListingDate, Length: 7895, dtype: datetime64[ns]

# %%
df["ListingDate"]=pd.to_datetime(df["ListingDate"])

# %%
df["ListingDate"]
# Out:
# 0      2002-04-23
# 1      2015-08-21
# 2      1999-08-11
# 3      2001-12-04
# 4      2017-04-07
#           ...
# 7890          NaT
# 7891   1976-06-29
# 7892   2000-02-03
# 7893          NaT
# 7894   2017-07-20
# Name: ListingDate, Length: 7895, dtype: datetime64[ns]

# %%
#ListingYear 파생변수 만들기

df["ListingDate"].dt.year
# Out:
# 0       2002.0
# 1       2015.0
# 2       1999.0
# 3       2001.0
# 4       2017.0
#          ...
# 7890       NaN
# 7891    1976.0
# 7892    2000.0
# 7893       NaN
# 7894    2017.0
# Name: ListingDate, Length: 7895, dtype: float64

# %%
#ListingYear 파생변수 만들기
#year변수로 넣어줌
df["ListingYear"]=df["ListingDate"].dt.year

# %%
df["ListingYear"]
# Out:
# 0       2002.0
# 1       2015.0
# 2       1999.0
# 3       2001.0
# 4       2017.0
#          ...
# 7890       NaN
# 7891    1976.0
# 7892    2000.0
# 7893       NaN
# 7894    2017.0
# Name: ListingYear, Length: 7895, dtype: float64

# %%
# 위에서 보면 Nan이 나오는데 not a number 약자로 결측치임
#결측치의 타입이 float임
import numpy as np
type(np.nan)
# Out:
# float

# %%
df
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7890  000545   KOSPI            흥국화재우                       NaN
# 7891  003280   KOSPI             흥아해운                    해상 운송업
# 7892  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7893  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7894  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...

# %%
df[["ListingYear","ListingDate"]]
# Out:
#       ListingYear ListingDate
# 0          2002.0  2002-04-23
# 1          2015.0  2015-08-21
# 2          1999.0  1999-08-11
# 3          2001.0  2001-12-04
# 4          2017.0  2017-04-07
# ...           ...         ...
# 7890          NaN         NaT
# 7891       1976.0  1976-06-29
# 7892       2000.0  2000-02-03
# 7893          NaN         NaT
# 7894       2017.0  2017-07-20
#
# [7895 rows x 2 columns]

# %%
df[["ListingYear","ListingDate"]].dtypes
# Out:
# ListingYear           float64
# ListingDate    datetime64[ns]
# dtype: object

# %% [markdown]
# # 지역별,년도별로 데이터를 다 뽑아 냈으니
# # matplotlib이용해 데이터 시각화

# %%
# 데이터 시각화 전 폰트 설정
import matplotlib.font_manager as fm
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmsy10',
#  'cmr10',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'cmex10',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'Arial',
#  'Rockwell Condensed',
#  'Adobe Arabic',
#  'Sitka Small',
#  'Verdana',
#  'Microsoft New Tai Lue',
#  'GyeonggiTitle',
#  'Playbill',
#  'Kozuka Gothic Pr6N',
#  'Trajan Pro',
#  'Cooper Blk BT',
#  'Haansoft Batang',
#  'Wingdings',
#  'MHunmin',
# ...

# %%
import matplotlib.pyplot as plt
font_family=plt.rcParams["font.family"]='Malgun Gothic'
plt.rc("axes",unicode_minus=False)
plt.style.use("ggplot")
pd.Series([1,3,5,7,9]).plot(title="한글폰트")
# Out:
# <AxesSubplot:title={'center':'한글폰트'}>

# %% [markdown]
# # 1.주식시장 별 상장주식 빈도수 시각화

# %%
#Market column에 어떤 데이터들이 있는지 unique로 확인  중복을 제거한 값이 나옴
df["Market"].unique()
# Out:
# array(['KOSDAQ', 'KOSPI', 'KONEX'], dtype=object)

# %%
# 국내주식 시장은  'KOSDAQ', 'KOSPI', 'KONEX' 가 있음
# value_counts()로 빈도수 구함
df["Market"].value_counts()
# Out:
# KOSPI     6195
# KOSDAQ    1570
# KONEX      130
# Name: Market, dtype: int64

# %%
# value_counts()로 빈도수 구함
df["Market"].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
# value_counts()로 빈도수 구함
df["Market"].value_counts().plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
#Seaborn countplot 활용해서 빈도수 표현
import seaborn as sns
sns.countplot(data=df, x="Market")
# Out:
# <AxesSubplot:xlabel='Market', ylabel='count'>

# %% [markdown]
# # 2.주식 섹터별 빈도수 구함.

# %%
df["Sector"]
# Out:
# 0                       전자부품 제조업
# 1                산업용 기계 및 장비 임대업
# 2                         기타 금융업
# 3                         기타 금융업
# 4                  특수 목적용 기계 제조업
#                   ...
# 7890                         NaN
# 7891                      해상 운송업
# 7892    건축기술, 엔지니어링 및 관련 기술 서비스업
# 7893                         NaN
# 7894               특수 목적용 기계 제조업
# Name: Sector, Length: 7895, dtype: object

# %%
#섹터별 갯수
df["Sector"].value_counts()
# Out:
# 소프트웨어 개발 및 공급업       154
# 특수 목적용 기계 제조업        145
# 전자부품 제조업             129
# 자동차 신품 부품 제조업         96
# 의약품 제조업               95
#                     ...
# 담배 제조업                 1
# 의복 액세서리 제조업            1
# 악기 제조업                 1
# 인형,장난감 및 오락용품 제조업      1
# 해체, 선별 및 원료 재생업        1
# Name: Sector, Length: 161, dtype: int64

# %%
# 갯수가 많은 순으로 다시 보여주기위해 일단 변수 하나생성
sector_count_top=df["Sector"].value_counts().head(30)
sector_count_top
# Out:
# 소프트웨어 개발 및 공급업                           154
# 특수 목적용 기계 제조업                            145
# 전자부품 제조업                                 129
# 자동차 신품 부품 제조업                             96
# 의약품 제조업                                   95
# 기타 금융업                                    94
# 기타 화학제품 제조업                               93
# 금융 지원 서비스업                                75
# 통신 및 방송 장비 제조업                            72
# 반도체 제조업                                   59
# 자연과학 및 공학 연구개발업                           59
# 의료용 기기 제조업                                57
# 1차 철강 제조업                                 57
# 일반 목적용 기계 제조업                             45
# 플라스틱제품 제조업                                45
# 기초 화학물질 제조업                               42
# 기초 의약물질 및 생물학적 제제 제조업                     40
# 기타 전문 도매업                                 38
# 컴퓨터 프로그래밍, 시스템 통합 및 관리업                   37
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업         35
# 기타 식품 제조업                                 34
# ...

# %%
sector_count_top.index
# Out:
# Index(['소프트웨어 개발 및 공급업', '특수 목적용 기계 제조업', '전자부품 제조업', '자동차 신품 부품 제조업',
#        '의약품 제조업', '기타 금융업', '기타 화학제품 제조업', '금융 지원 서비스업', '통신 및 방송 장비 제조업',
#        '반도체 제조업', '자연과학 및 공학 연구개발업', '의료용 기기 제조업', '1차 철강 제조업',
#        '일반 목적용 기계 제조업', '플라스틱제품 제조업', '기초 화학물질 제조업', '기초 의약물질 및 생물학적 제제 제조업',
#        '기타 전문 도매업', '컴퓨터 프로그래밍, 시스템 통합 및 관리업',
#        '전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업', '기타 식품 제조업',
#        '영화, 비디오물, 방송프로그램 제작 및 배급업', '의료용품 및 기타 의약 관련제품 제조업', '봉제의복 제조업',
#        '기계장비 및 관련 물품 도매업', '기타 금속 가공제품 제조업',
#        '측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외', '건물 건설업', '부동산 임대 및 공급업',
#        '구조용 금속제품, 탱크 및 증기발생기 제조업'],
#       dtype='object')

# %%
#isin() 함수를 사용하여 특정 조건의 값 추출
df["Sector"].isin(sector_count_top.index)
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 7890    False
# 7891    False
# 7892    False
# 7893    False
# 7894     True
# Name: Sector, Length: 7895, dtype: bool

# %%
df[df["Sector"].isin(sector_count_top.index)]
# Out:
#       Symbol  Market    Name                 Sector  \
# 0     060310  KOSDAQ      3S               전자부품 제조업
# 2     006840   KOSPI   AK홀딩스                 기타 금융업
# 3     054620  KOSDAQ  APS홀딩스                 기타 금융업
# 4     265520  KOSDAQ   AP시스템          특수 목적용 기계 제조업
# 5     211270  KOSDAQ    AP위성         통신 및 방송 장비 제조업
# ...      ...     ...     ...                    ...
# 7883  145020  KOSDAQ      휴젤  기초 의약물질 및 생물학적 제제 제조업
# 7884  069260   KOSPI     휴켐스            기타 화학제품 제조업
# 7885  024060  KOSDAQ    흥구석유              기타 전문 도매업
# 7886  010240  KOSDAQ      흥국          특수 목적용 기계 제조업
# 7894  238490  KOSDAQ      힘스          특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...

# %%
df_sector_30=df[df["Sector"].isin(sector_count_top.index)]

# %%
# 섹터별로 많은순으로 30개만 뽑아내봄.
plt.figure(figsize=(10,8))
sns.countplot(data=df_sector_30, y="Sector")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Sector'>

# %%
#색깔 뭐있는지 확인
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %%
# 보기좋게 빈도수가 많은순으로 정렬
#빈도수가 가장 많은 데이터를 색인하기
#빈도수 색깔을 blues로했는데 색깔 진한거를 많은순으로 바꾸고 싶으면 색깔뒤에 _r 붙여주면 뒤바뀜
# 타이틀 지정
plt.figure(figsize=(10,8))
sns.countplot(data=df_sector_30, y="Sector",palette="Blues_r",order=sector_count_top.index).set_title("섹터별 빈도수")
# Out:
# Text(0.5, 1.0, '섹터별 빈도수')

# %% [markdown]
# # 3.주식 산업별 빈도수 데이터분석

# %%
df
# Out:
#       Symbol  Market             Name                    Sector  \
# 0     060310  KOSDAQ               3S                  전자부품 제조업
# 1     095570   KOSPI           AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI            AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ           APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ            AP시스템             특수 목적용 기계 제조업
# ...      ...     ...              ...                       ...
# 7890  000545   KOSPI            흥국화재우                       NaN
# 7891  003280   KOSPI             흥아해운                    해상 운송업
# 7892  037440  KOSDAQ               희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 7893  419890   KOSPI  히어로즈 단기채권ESG액티브                       NaN
# 7894  238490  KOSDAQ               힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# ...

# %%
df["Industry"]
# Out:
# 0                          반도체 웨이퍼 캐리어
# 1                  렌탈(파렛트, OA장비, 건설장비)
# 2                                 지주사업
# 3                          인터넷 트래픽 솔루션
# 4                          디스플레이 제조 장비
#                      ...
# 7890                               NaN
# 7891                    외항화물운송업(케미컬탱커)
# 7892                         설계 및 감리용역
# 7893                               NaN
# 7894    OLED Mask 인장기, OLED Mask 검사기 등
# Name: Industry, Length: 7895, dtype: object

# %%
df["Industry"].value_counts().head(30)
# Out:
# 기업인수합병        28
# 지주회사          20
# 지주사업           9
# 모바일게임          7
# 화장품            7
# 기업인수 및 합병      6
# 금융 지원 서비스      5
# 기업 인수 및 합병     5
# -              4
# 부동산투자          4
# 합병             4
# 셋톱박스           3
# 금융 지원 서비스업     3
# 벤처캐피탈          3
# 금융지원 서비스       3
# 도급공사           3
# 자동차부품          3
# 의약품            3
# 건강기능식품         3
# 금융지주회사         3
# 증권업            3
# 화장품 용기         2
# 백화점            2
# 엔진부품           2
# 레미콘            2
# 비금융지주회사        2
# 카지노            2
# 원료의약품          2
# 이미지센서 패키징      2
# 의료기기           2
# Name: Industry, dtype: int64

# %%
industry_count_top=df["Industry"].value_counts().head(30)
industry_count_top.index
# Out:
# Index(['기업인수합병', '지주회사', '지주사업', '모바일게임', '화장품', '기업인수 및 합병', '금융 지원 서비스',
#        '기업 인수 및 합병', '-', '부동산투자', '합병', '셋톱박스', '금융 지원 서비스업', '벤처캐피탈',
#        '금융지원 서비스', '도급공사', '자동차부품', '의약품', '건강기능식품', '금융지주회사', '증권업', '화장품 용기',
#        '백화점', '엔진부품', '레미콘', '비금융지주회사', '카지노', '원료의약품', '이미지센서 패키징', '의료기기'],
#       dtype='object')

# %%
df[df["Industry"].isin(industry_count_top.index)]
# Out:
#       Symbol  Market     Name                             Sector  Industry  \
# 2     006840   KOSPI    AK홀딩스                             기타 금융업      지주사업
# 50    027410   KOSPI      BGF                             기타 금융업      지주회사
# 53    138930   KOSPI  BNK금융지주                             기타 금융업    금융지주회사
# 56    013720  KOSDAQ      CBI                      자동차 신품 부품 제조업      엔진부품
# 57    001040   KOSPI       CJ                             기타 금융업      지주회사
# ...      ...     ...      ...                                ...       ...
# 7849  126640  KOSDAQ     화신정공                      자동차 신품 부품 제조업     자동차부품
# 7859  298040   KOSPI    효성중공업  전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업         -
# 7862  298000   KOSPI     효성화학                        기초 화학물질 제조업         -
# 7868  353190  KOSDAQ       휴럼                          기타 식품 제조업  금융지원 서비스
# 7871  115160  KOSDAQ      휴맥스                      영상 및 음향기기 제조업      셋톱박스
#
#      ListingDate SettleMonth     Representative  \
# ...

# %%
#seaborn
plt.figure(figsize=(10,8))

sns.countplot(data=df[df["Industry"].isin(industry_count_top.index)],y="Industry")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Industry'>

# %%
#seaborn
plt.figure(figsize=(10,8))

sns.countplot(data=df[df["Industry"].isin(industry_count_top.index)],y="Industry",order=industry_count_top.index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Industry'>

# %% [markdown]
# # 4.주식 지역별 데이터분석

# %%
df["Region"]
# Out:
# 0       서울특별시
# 1       서울특별시
# 2       서울특별시
# 3         경기도
# 4         경기도
#         ...
# 7890      NaN
# 7891    서울특별시
# 7892    서울특별시
# 7893      NaN
# 7894    인천광역시
# Name: Region, Length: 7895, dtype: object

# %%
df["Region"].value_counts().head(30)
# Out:
# 서울특별시      1017
# 경기도         709
# 충청남도         98
# 경상남도         90
# 인천광역시        87
# 충청북도         85
# 부산광역시        77
# 경상북도         64
# 대구광역시        53
# 대전광역시        52
# 전라북도         29
# 강원도          27
# 울산광역시        26
# 전라남도         22
# 광주광역시        22
# 세종특별자치시      10
# 제주특별자치도       9
# 홍콩            8
# 미국            6
# 케이맨 제도        5
# 일본            3
# 싱가포르          1
# Name: Region, dtype: int64

# %%
#Region의 빈도수를 seaborn으로 표시
plt.figure(figsize=(10,8))

sns.countplot(data=df, y="Region")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Region'>

# %%
plt.figure(figsize=(10,8))

sns.countplot(data=df, y="Region",
              order=df["Region"].value_counts().index).set_title("지역별 상장 종목수")
# Out:
# Text(0.5, 1.0, '지역별 상장 종목수')

# %% [markdown]
# # 위에서 시장,섹터,산업,지역 별로 빈도수 를 구했으니 두개 이상의 빈도수구하기

# %% [markdown]
# ## 1.시장+지역별로 구해봄.

# %%
# Market과 Region으로 빈도수 구하기
pd.crosstab(df["Market"],df["Region"])
# Out:
# Region  강원도  경기도  경상남도  경상북도  광주광역시  대구광역시  대전광역시  미국  부산광역시  서울특별시  ...  \
# Market                                                               ...
# KONEX     6   33     1     5      4      1      7   0      2     48  ...
# KOSDAQ   17  526    47    40      9     31     38   6     40    547  ...
# KOSPI     4  150    42    19      9     21      7   0     35    422  ...
#
# Region  울산광역시  인천광역시  일본  전라남도  전라북도  제주특별자치도  충청남도  충청북도  케이맨 제도  홍콩
# Market
# KONEX       0      4   0     3     1        1     4     9       0   0
# KOSDAQ      9     59   3    12    16        2    68    61       4   8
# KOSPI      17     24   0     7    12        6    26    15       1   0
#
# [3 rows x 22 columns]

# %%
sns.countplot(data=df, x="Market")
# Out:
# <AxesSubplot:xlabel='Market', ylabel='count'>

# %%
sns.countplot(data=df, x="Region")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
# hue는 범주형 데이터에서 색깔별로 시각화 해줌
plt.figure(figsize=(12,9))

sns.countplot(data=df, x="Region",hue="Market")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
# hue는 범주형 데이터에서 색깔별로 시각화 해줌
plt.figure(figsize=(14,8))
#plt.xticks(rotation=90) #글씨를 90도로 나오게 해줌
#x축을 y축으로 바꾸면 더 낳음
#로그 안나오게 하려면 변수에 넣어줌

#countplot(data=dataframe,y="y축", hue=데이터 column)
#y는 countplot를 어떤 부분을 count할지 정해줌
# data는 사용할 data를 정의
#hue는 정한 데이터를 다시 hue기준으로 더 나누어서 count 해줌.
g=sns.countplot(data=df, y="Region",hue="Market").set_title("마켓별 지역별 빈도수")

# %% [markdown]
# ## 2.시장+연도별 구해봄.

# %%
pd.crosstab(df["Market"],df["ListingYear"])
# Out:
# ListingYear  1956.0  1962.0  1964.0  1966.0  1968.0  1969.0  1970.0  1971.0  \
# Market
# KONEX             0       0       0       0       0       0       0       0
# KOSDAQ            0       0       0       0       0       0       0       0
# KOSPI             5       1       1       1       6       5       4       1
#
# ListingYear  1972.0  1973.0  ...  2013.0  2014.0  2015.0  2016.0  2017.0  \
# Market                       ...
# KONEX             0       0  ...      11      10      25      22      16
# KOSDAQ            0       0  ...      35      58      89      61      68
# KOSPI             3      22  ...      10       9      18      18      20
#
# ListingYear  2018.0  2019.0  2020.0  2021.0  2022.0
# Market
# KONEX            13      14      11       7       1
# KOSDAQ           85      92      86     100      21
# KOSPI            19      15      14      27       1
#
# [3 rows x 58 columns]

# %%
#연도가 많아서 잘안보임

sns.countplot(data=df, x="ListingYear")
# Out:
# <AxesSubplot:xlabel='ListingYear', ylabel='count'>

# %%
#hue를 사용해 다른 변수를 함께 표현. hue는 색상을 의미
# 차트 사이즈 키워주고
# 년도를 세로로 해서 잘보이게 정렬
#x축은 년도 hue를통해 시장을 더 쪼개서 보여줌
plt.figure(figsize=(14,8))
plt.xticks(rotation=90)
g=sns.countplot(data=df, x="ListingYear",hue="Market")

# %% [markdown]
# # 3. 응용 분석 ( 2018년에 상장한,서울특별시에 소재한  코스피종목 찾아봄.)

# %%
df[df["Region"]=="서울특별시"]
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S                  전자부품 제조업
# 1     095570   KOSPI  AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI   AK홀딩스                    기타 금융업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 50    027410   KOSPI     BGF                    기타 금융업
# ...      ...     ...     ...                       ...
# 7884  069260   KOSPI     휴켐스               기타 화학제품 제조업
# 7887  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 7888  000540   KOSPI    흥국화재                       보험업
# 7891  003280   KOSPI    흥아해운                    해상 운송업
# 7892  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
#
#                        Industry ListingDate SettleMonth        Representative  \
# 0                   반도체 웨이퍼 캐리어  2002-04-23         03월                   김세완
# 1           렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월                   박대현
# ...

# %%
#년도별 요약
df["ListingYear"].describe()
# Out:
# count    2500.000000
# mean     2005.676000
# std        12.913657
# min      1956.000000
# 25%      1999.000000
# 50%      2008.000000
# 75%      2016.000000
# max      2022.000000
# Name: ListingYear, dtype: float64

# %%
df[(df["ListingYear"]==2018)]
# Out:
#       Symbol  Market       Name                             Sector  \
# 97    245620  KOSDAQ       EDGC                    자연과학 및 공학 연구개발업
# 159   294870   KOSPI  HDC현대산업개발                             건물 건설업
# 184   950170  KOSDAQ        JTC                             종합 소매업
# 1801  255220  KOSDAQ         SG                    기타 비금속 광물제품 제조업
# 1835  285130   KOSPI      SK케미칼                 합성고무 및 플라스틱 물질 제조업
# ...      ...     ...        ...                                ...
# 7859  298040   KOSPI      효성중공업  전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 7860  298050   KOSPI     효성첨단소재                           화학섬유 제조업
# 7861  298020   KOSPI      효성티앤씨                           화학섬유 제조업
# 7862  298000   KOSPI       효성화학                        기초 화학물질 제조업
# 7866  290270  KOSDAQ       휴네시온                     소프트웨어 개발 및 공급업
#
#                             Industry ListingDate SettleMonth  \
# 97                     유전체 분석 진단 서비스  2018-06-26         12월
# ...

# %%
#서울에 있는 회사 찾기
#2019년에 상장한 서울특별시에 소재한 코스피 종목 찾아봄. 없으면 코스닥

df[(df["ListingYear"]==2018) &  (df["Region"]=="서울특별시") & (df["Market"]=="KOSPI")]
# Out:
#       Symbol Market       Name                             Sector  \
# 159   294870  KOSPI  HDC현대산업개발                             건물 건설업
# 2551  286940  KOSPI     롯데정보통신            컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 4265  306200  KOSPI       세아제강                          1차 철강 제조업
# 4682  293940  KOSPI     신한알파리츠                       부동산 임대 및 공급업
# 4765  267850  KOSPI    아시아나IDT            컴퓨터 프로그래밍, 시스템 통합 및 관리업
# 4830  018250  KOSPI       애경산업                        기타 화학제품 제조업
# 5117  010400  KOSPI    우진아이엔에스                        건물설비 설치 공사업
# 5246  088260  KOSPI     이리츠코크렙                       부동산 임대 및 공급업
# 5728  091810  KOSPI      티웨이항공                          항공 여객 운송업
# 7732  300720  KOSPI      한일시멘트           시멘트, 석회, 플라스터 및 그 제품 제조업
# 7859  298040  KOSPI      효성중공업  전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 7860  298050  KOSPI     효성첨단소재                           화학섬유 제조업
# 7861  298020  KOSPI      효성티앤씨                           화학섬유 제조업
# ...

# %% [markdown]
# # 개별 종목 시세 수집 및 시각화
#
# ## FinanceDataReader 라이브러리를 통해 종목별 일별시세를 바로 불러올수 있음

# %%
# 삼성전자의 주가 확인

# datareader('종목코드', '시작일','종료일')
# 일별시세 확인
df=fdr.DataReader('005930',"2017","2021")
df.head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2017-01-02  35980  36240  35880  36100   93012  0.001665
# 2017-01-03  36280  36620  36020  36480  147153  0.010526
# 2017-01-04  36500  36520  36100  36160  159435 -0.008772
# 2017-01-05  36060  36060  35540  35560  219349 -0.016593
# 2017-01-06  36180  36440  36040  36200  177619  0.017998

# %%
#종가
df["Close"]
# Out:
# Date
# 2017-01-02    36100
# 2017-01-03    36480
# 2017-01-04    36160
# 2017-01-05    35560
# 2017-01-06    36200
#               ...
# 2020-12-23    73900
# 2020-12-24    77800
# 2020-12-28    78700
# 2020-12-29    78300
# 2020-12-30    81000
# Name: Close, Length: 981, dtype: int64

# %%
df["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# csv파일에 저장되어있는 데이터와  라이브러리를 통한 종목별 시세를 같이사용해서 종목별 시세 뽑아봄.
df_krx=pd.read_csv("krx.csv")
df_krx.shape
# Out:
# (7895, 10)

# %%
# 우선 종목에 대한 종목코드를 알아야 일별 시세를 불러올수 있음
df_krx[["Symbol","Name"]].head()
# Out:
#    Symbol    Name
# 0  060310      3S
# 1  095570  AJ네트웍스
# 2  006840   AK홀딩스
# 3  054620  APS홀딩스
# 4  265520   AP시스템

# %%
df_krx["Name"]
# Out:
# 0                    3S
# 1                AJ네트웍스
# 2                 AK홀딩스
# 3                APS홀딩스
# 4                 AP시스템
#              ...
# 7890              흥국화재우
# 7891               흥아해운
# 7892                 희림
# 7893    히어로즈 단기채권ESG액티브
# 7894                 힘스
# Name: Name, Length: 7895, dtype: object

# %%
df_krx["Name"] == "삼성전자"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7890    False
# 7891    False
# 7892    False
# 7893    False
# 7894    False
# Name: Name, Length: 7895, dtype: bool

# %%
df_krx[df_krx["Name"] == "삼성전자"]
# Out:
#       Symbol Market  Name          Sector  \
# 4139  005930  KOSPI  삼성전자  통신 및 방송 장비 제조업
#
#                                                Industry ListingDate  \
# 4139  IMT2000 서비스용 동기식 기지국,교환국장비,데이터단말기,동영상휴대폰,핵심칩,반...  1975-06-11
#
#      SettleMonth Representative              HomePage Region
# 4139         12월            한종희  http://www.sec.co.kr    경기도

# %%
df_krx.loc[df_krx["Name"] == "삼성전자","Symbol"]
# Out:
# 4139    005930
# Name: Symbol, dtype: object

# %%
#우리는 시리즈 형태를 원하는게 아니고 여기서 종목코드만 뽑아 내고싶음
df_krx.loc[df_krx["Name"] == "삼성전자","Symbol"].tolist()
# Out:
# ['005930']

# %%
#위에처럼 리스트 형태가 아니라 0번째 인덱스값 가져옴 string형태로
df_krx.loc[df_krx["Name"] == "삼성전자","Symbol"].tolist()[0]
# Out:
# '005930'

# %%
# 종목명을 item_name변수로 바꿔서 넣어줌
item_name="삼성전자"
df_krx.loc[df_krx["Name"] == item_name,"Symbol"].tolist()[0]
# Out:
# '005930'

# %% [markdown]
# ##  1.종목명으로 종목코드를 찾을수 있게 함

# %%
# item_code_by_item_name 함수씀

def item_code_by_item_name(item_name):
   
    return item_name

# %%
item_code_by_item_name(item_name)
# Out:
# '삼성전자'

# %%
def item_code_by_item_name(item_name):
    
    item_code=df_krx.loc[df_krx["Name"] == item_name,"Symbol"].tolist()[0]
    
    return item_code
item_code_by_item_name(item_name)
# Out:
# '005930'

# %%
item_code_by_item_name('하이브')
# Out:
# '352820'

# %%
item_code_by_item_name('LG에너지솔루션')
# Out:
# '373220'

# %%
#종목코드 대신에 종목명만 넣으면 바로 시세를 알수있게 바꿈.
fdr.DataReader(item_code_by_item_name("삼성전자"))
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 1998-01-23   1234   1263   1200   1262    616720       NaN
# 1998-01-24   1288   1361   1270   1362    467950  0.079239
# 1998-01-26   1377   1468   1377   1461   1244670  0.072687
# 1998-01-30   1577   1577   1561   1578    700090  0.080082
# 1998-01-31   1702   1702   1577   1616    871390  0.024081
# ...           ...    ...    ...    ...       ...       ...
# 2022-03-03  72300  73100  72200  72900  13232638  0.016736
# 2022-03-04  72700  72700  71200  71500  13409634 -0.019204
# 2022-03-07  70000  70600  69900  70100  18617138 -0.019580
# 2022-03-08  68800  70000  68700  69500  15828269 -0.008559
# 2022-03-10  70800  71200  70600  70700  10972325  0.017266
#
# [6000 rows x 6 columns]

# %% [markdown]
# ## 2.종목명으로 일별시세까지 같이 불러오기

# %%
def find_item_list(item_name,year=2021):
    
    item_code=item_code_by_item_name(item_name)
    if item_code:
        df_day=fdr.DataReader(item_code,str(year))
        return df_day
    else:
        return False

# %%
find_item_list("삼성전자",2021)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2022-03-03  72300  73100  72200  72900  13232638  0.016736
# 2022-03-04  72700  72700  71200  71500  13409634 -0.019204
# 2022-03-07  70000  70600  69900  70100  18617138 -0.019580
# 2022-03-08  68800  70000  68700  69500  15828269 -0.008559
# 2022-03-10  70800  71200  70600  70700  10972325  0.017266
#
# [292 rows x 6 columns]

# %%
stock_daily=find_item_list("삼성전자",2021)
stock_daily
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170
# ...           ...    ...    ...    ...       ...       ...
# 2022-03-03  72300  73100  72200  72900  13232638  0.016736
# 2022-03-04  72700  72700  71200  71500  13409634 -0.019204
# 2022-03-07  70000  70600  69900  70100  18617138 -0.019580
# 2022-03-08  68800  70000  68700  69500  15828269 -0.008559
# 2022-03-10  70800  71200  70600  70700  10972325  0.017266
#
# [292 rows x 6 columns]

# %%
stock_daily["Close"]
# Out:
# Date
# 2021-01-04    83000
# 2021-01-05    83900
# 2021-01-06    82200
# 2021-01-07    82900
# 2021-01-08    88800
#               ...
# 2022-03-03    72900
# 2022-03-04    71500
# 2022-03-07    70100
# 2022-03-08    69500
# 2022-03-10    70700
# Name: Close, Length: 292, dtype: int64

# %% [markdown]
# ## 3.일별시세를 시각화 해보기

# %%
#삼성전자 시세 시각화
#종가만 시각화
plt.figure(figsize=(10,8))
stock_daily["Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_daily.plot(figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#수집한 종목의 선그래프를 pandas로 그림
# 스케일이 다르기 때문에 subplots를 사용해 그려봄.
g=stock_daily.plot(subplots=True)

# %%
g=stock_daily.plot(subplots=True,figsize=(10,8))

# %%
#히스토그램도 그려봄
#삼성전자 시세 히스토그램
stock_daily.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'High'}>],
#        [<AxesSubplot:title={'center':'Low'}>,
#         <AxesSubplot:title={'center':'Close'}>],
#        [<AxesSubplot:title={'center':'Volume'}>,
#         <AxesSubplot:title={'center':'Change'}>]], dtype=object)

# %%
h=stock_daily.hist(figsize=(10,8))

# %%
#막대 더쪼갬
h=stock_daily.hist(figsize=(10,8),bins=20)

# %%
#이번엔 종가와 거래량만 가져와서 그려보기
stock_daily[["Close","Volume"]].plot(figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# secondary_y 옵션을 통한 종가와 거래량에 대한 2축 그래프
stock_daily[["Close","Volume"]].plot(secondary_y="Volume",figsize=(10,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # 이제 22년 투자할만한 종목 뽑아보기

# %%
# krx거래소에서 주식데이터의 정보가 들어있는 csv파일 저장 후 불러옴.
import pandas as pd
df1=pd.read_csv("per.csv",encoding='cp949')
df1
# Out:
#         종목코드       종목명     종가   대비   등락률     EPS     PER  선행 EPS  선행 PER  \
# 0     060310       3S    3105  -55 -1.74    16.0  194.06     NaN     NaN
# 1     095570   AJ네트웍스    5560   20  0.36     NaN     NaN     NaN     NaN
# 2     006840    AK홀딩스   20300 -350 -1.69     NaN     NaN     NaN     NaN
# 3     054620   APS홀딩스   11850 -200 -1.66     NaN     NaN     NaN     NaN
# 4     265520    AP시스템   24000  250  1.05  1736.0   13.82  3190.0    7.52
# ...      ...       ...    ...  ...   ...     ...     ...     ...     ...
# 2439  000547  흥국화재2우B   28100 -700 -2.43     NaN     NaN     NaN     NaN
# 2440  000545    흥국화재우    7850 -210 -2.61     NaN     NaN     NaN     NaN
# 2441  003280     흥아해운    3225 -145 -4.30     NaN     NaN     NaN     NaN
# 2442  037440       희림    8510  190  2.28   389.0   21.88     NaN     NaN
# 2443  238490       힘스    9460  -80 -0.84  1522.0    6.22     NaN     NaN
#
#           BPS   PBR  주당배당금  배당수익률
# 0       792.0  3.92      0   0.00
# ...

# %%
df1.shape
# Out:
# (2444, 13)

# %% [markdown]
# # per(주가수익비율) 로 저평가되어있는 주식 뽑아보기
#
# ## per란 한국말로 주가수익비율을 뜻합니다. 간단하게 말하면
# ## 기업의 순이익에 비해 주식 가격이 높게(고평가) 또는 낮게(저평가)를 판단
# ## per가 낮을수록 해당 기업의 가치가 저평가 되어있다고 볼수 있음.

# %%
df1[["종목명","PER"]]
# Out:
#            종목명     PER
# 0          3S   194.06
# 1      AJ네트웍스      NaN
# 2       AK홀딩스      NaN
# 3      APS홀딩스      NaN
# 4       AP시스템    13.82
# ...        ...     ...
# 2439  흥국화재2우B      NaN
# 2440    흥국화재우      NaN
# 2441     흥아해운      NaN
# 2442       희림    21.88
# 2443       힘스     6.22
#
# [2444 rows x 2 columns]

# %% [markdown]
# # per주가수익비율이 1보다 작은 종목뽑아봄.
# # 1이라고 나오는건 예를들어 주가가 1주에 10만원인데
# # 1년에 순이익을 1주당 10만원 내면   1이다.
# # 굉장히 주가대비 종목이 저평가 되어있다 볼수있다.
# # 저평가가 되었다는말은 주식가격이 종목 순이익에 비해 싸다는뜻

# %%
df1[df1["PER"]<1]
# Out:
#         종목코드       종목명     종가   대비   등락률       EPS   PER  선행 EPS  선행 PER  \
# 1000  037350    성도이엔지    5160   20  0.39    6074.0  0.85     NaN     NaN
# 1071  036830  솔브레인홀딩스   27950 -100 -0.36  106557.0  0.26     NaN     NaN
# 2334  034810     해성산업   11950    0  0.00   25207.0  0.47     NaN     NaN
#
#           BPS   PBR  주당배당금  배당수익률
# 1000  14797.0  0.35    200   3.88
# 1071  49397.0  0.57      0   0.00
# 2334  32729.0  0.37    175   1.46

# %% [markdown]
# # 현실적으로 1밑으로는 너무 없다 보니 3정도로 보고 뽑아봄

# %%
per=df1[df1["PER"]<3]
per
# Out:
#         종목코드        종목명     종가   대비   등락률       EPS   PER   선행 EPS  선행 PER  \
# 26    023460       CNH    2105  -45 -2.09     824.0  2.55      NaN     NaN
# 36    016610    DB금융투자    6080  -30 -0.49    2327.0  2.61      NaN     NaN
# 126   092230    KPX홀딩스   60100 -100 -0.17   34397.0  1.75      NaN     NaN
# 190   040610      SG&G    2195  -55 -2.44     787.0  2.79      NaN     NaN
# 194   016250  SGC이테크건설   56800 -900 -1.56   43859.0  1.30  20841.0    2.73
# 209   006120   SK디스커버리   39000    0  0.00   13096.0  2.98      NaN     NaN
# 392   137940     넥스트아이    1195  -10 -0.83     570.0  2.10      NaN     NaN
# 440   008060        대덕    7200  -70 -0.96    3409.0  2.11      NaN     NaN
# 696   016100   리더스코스메틱    2295  -20 -0.86    1313.0  1.75      NaN     NaN
# 710   038290      마크로젠   25650  150  0.59    9002.0  2.85      NaN     NaN
# 767   007120    미래아이앤지     398   -3 -0.75     153.0  2.60      NaN     NaN
# ...

# %% [markdown]
# # per가3보다 낮은 종목명만 뽑아봄.

# %%
stock_list=per[["종목명","종목코드"]].values
stock_list
# Out:
# array([['CNH ', '023460'],
#        ['DB금융투자 ', '016610'],
#        ['KPX홀딩스 ', '092230'],
#        ['SG&G ', '040610'],
#        ['SGC이테크건설 ', '016250'],
#        ['SK디스커버리 ', '006120'],
#        ['넥스트아이 ', '137940'],
#        ['대덕 ', '008060'],
#        ['리더스코스메틱 ', '016100'],
#        ['마크로젠 ', '038290'],
#        ['미래아이앤지 ', '007120'],
#        ['삼정펄프 ', '009770'],
#        ['서희건설 ', '035890'],
#        ['선진 ', '136490'],
#        ['성도이엔지 ', '037350'],
#        ['세원물산 ', '024830'],
#        ['솔브레인홀딩스 ', '036830'],
#        ['신영증권 ', '001720'],
#        ['신풍제지 ', '002870'],
#        ['원림 ', '005820'],
#        ['원익 ', '032940'],
#        ['유성티엔에스 ', '024800'],
#        ['유수홀딩스 ', '000700'],
#        ['이베스트투자증권 ', '078020'],
#        ['이지바이오 ', '353810'],
#        ['이지홀딩스 ', '035810'],
#        ['젠큐릭스 ', '229000'],
#        ['초록뱀컴퍼니 ', '052300'],
#        ['케이엠 ', '083550'],
#        ['코오롱 ', '002020'],
#        ['태영건설 ', '009410'],
#        ['티와이홀딩스 ', '363280'],
# ...

# %% [markdown]
# # 위에서 뽑아본 per가 3보다 낮은 종목들의 종가(Close)가져오기

# %%
import pandas as pd

df_list=[fdr.DataReader(code,'2021-02-26')['Close']for name, code in stock_list]
len(df_list)
# Out:
# 37

# %%
#pd.concat()로 합치기

df1=pd.concat(df_list,axis=1)
df1.columns=[name for name, code in stock_list]
df1
# Out:
#             CNH   DB금융투자   KPX홀딩스   SG&G   SGC이테크건설   SK디스커버리   넥스트아이    대덕   \
# Date
# 2021-02-26  2585     5730    57500   2450      39446     65400    1315  6700
# 2021-03-02  2620     5730    57500   2450      39524     65300    1300  6710
# 2021-03-03  2635     5900    57200   2545      39679     63000    1270  6900
# 2021-03-04  2610     5850    56400   2630      39524     60300    1245  6830
# 2021-03-05  2580     5800    55900   2465      39446     59800    1255  6760
# ...          ...      ...      ...    ...        ...       ...     ...   ...
# 2022-03-03  2160     6280    61100   2285      58800     40850    1240  7540
# 2022-03-04  2165     6270    60600   2325      58900     39950    1250  7460
# 2022-03-07  2150     6110    60200   2250      57700     39000    1205  7270
# 2022-03-08  2065     6020    59900   2200      56600     38850    1245  7170
# 2022-03-10  2135     6270    60100   2550      57900     39250    1255  7340
#
# ...

# %%
df1.plot(figsize=(14,13))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # 종목이 너무 많으니 조건을 하나 더 추가
# # PBR 주당 순자산 비율을 뜻함.
# # 간단하게 말하자면 주가가 순자산(자본금과 자본잉여금,
# # 이익잉여금의 합계)에 비해 1주당 몇 배로 거래되고 있는지 측정

# %% [markdown]
# ## pbr이 낮으면 주식의 재무구조가 안정적이라, 기업의 수익렬과 성장력이 높다고 할수있음. 그래서 pbr이 낮고+ per가 낮은 종목으로 더 추려봄

# %%
# krx거래소에서 주식데이터의 정보가 들어있는 csv파일 저장 후 불러옴.
import pandas as pd
df3=pd.read_csv("per.csv",encoding='cp949')
df3
# Out:
#         종목코드       종목명     종가   대비   등락률     EPS     PER  선행 EPS  선행 PER  \
# 0     060310       3S    3105  -55 -1.74    16.0  194.06     NaN     NaN
# 1     095570   AJ네트웍스    5560   20  0.36     NaN     NaN     NaN     NaN
# 2     006840    AK홀딩스   20300 -350 -1.69     NaN     NaN     NaN     NaN
# 3     054620   APS홀딩스   11850 -200 -1.66     NaN     NaN     NaN     NaN
# 4     265520    AP시스템   24000  250  1.05  1736.0   13.82  3190.0    7.52
# ...      ...       ...    ...  ...   ...     ...     ...     ...     ...
# 2439  000547  흥국화재2우B   28100 -700 -2.43     NaN     NaN     NaN     NaN
# 2440  000545    흥국화재우    7850 -210 -2.61     NaN     NaN     NaN     NaN
# 2441  003280     흥아해운    3225 -145 -4.30     NaN     NaN     NaN     NaN
# 2442  037440       희림    8510  190  2.28   389.0   21.88     NaN     NaN
# 2443  238490       힘스    9460  -80 -0.84  1522.0    6.22     NaN     NaN
#
#           BPS   PBR  주당배당금  배당수익률
# 0       792.0  3.92      0   0.00
# ...

# %%
df3[df3["PBR"]<0.5]
# Out:
#         종목코드       종목명     종가    대비   등락률     EPS    PER  선행 EPS  선행 PER  \
# 2     006840    AK홀딩스   20300  -350 -1.69     NaN    NaN     NaN     NaN
# 6     027410      BGF    5220    10  0.19   285.0  18.32   150.0   34.76
# 9     138930  BNK금융지주    7360  -110 -1.47  1498.0   4.91  2695.0    2.73
# 31    000590    CS홀딩스   68100 -1100 -1.59  6657.0  10.23     NaN     NaN
# 36    016610   DB금융투자    6080   -30 -0.49  2327.0   2.61     NaN     NaN
# ...      ...       ...    ...   ...   ...     ...    ...     ...     ...
# 2404  000850     화천기공   32100  -300 -0.93  2053.0  15.64     NaN     NaN
# 2422  115160      휴맥스    4125     5  0.12     NaN    NaN     NaN     NaN
# 2423  028080   휴맥스홀딩스    4100   -95 -2.26     NaN    NaN     NaN     NaN
# 2429  005010      휴스틸   17850 -1450 -7.51  1134.0  15.74     NaN     NaN
# 2438  000540     흥국화재    3730     0  0.00   268.0  13.92     NaN     NaN
#
#            BPS   PBR  주당배당금  배당수익률
# 2      50471.0  0.40    400   1.97
# ...

# %%
per=df3[(df3["PER"]<3) & (df3["PBR"]<0.5)]
per
# Out:
#         종목코드       종목명     종가   대비   등락률      EPS   PER  선행 EPS  선행 PER  \
# 36    016610   DB금융투자    6080  -30 -0.49   2327.0  2.61     NaN     NaN
# 126   092230   KPX홀딩스   60100 -100 -0.17  34397.0  1.75     NaN     NaN
# 190   040610     SG&G    2195  -55 -2.44    787.0  2.79     NaN     NaN
# 209   006120  SK디스커버리   39000    0  0.00  13096.0  2.98     NaN     NaN
# 440   008060       대덕    7200  -70 -0.96   3409.0  2.11     NaN     NaN
# 932   009770     삼정펄프   27550 -650 -2.30  10743.0  2.56     NaN     NaN
# 1000  037350    성도이엔지    5160   20  0.39   6074.0  0.85     NaN     NaN
# 1031  024830     세원물산    6280    0  0.00   2199.0  2.86     NaN     NaN
# 1534  005820       원림   20900 -800 -3.69   7819.0  2.67     NaN     NaN
# 1537  032940       원익    4385  -15 -0.34   4368.0  1.00     NaN     NaN
# 1594  024800   유성티엔에스    2990  -25 -0.83   2123.0  1.41     NaN     NaN
# 1595  000700    유수홀딩스    5520  -60 -1.08   3202.0  1.72     NaN     NaN
# ...

# %%
stock_list=per[["종목명","종목코드"]].values
stock_list
# Out:
# array([['DB금융투자 ', '016610'],
#        ['KPX홀딩스 ', '092230'],
#        ['SG&G ', '040610'],
#        ['SK디스커버리 ', '006120'],
#        ['대덕 ', '008060'],
#        ['삼정펄프 ', '009770'],
#        ['성도이엔지 ', '037350'],
#        ['세원물산 ', '024830'],
#        ['원림 ', '005820'],
#        ['원익 ', '032940'],
#        ['유성티엔에스 ', '024800'],
#        ['유수홀딩스 ', '000700'],
#        ['이지홀딩스 ', '035810'],
#        ['한솔홀딩스 ', '004150'],
#        ['한신공영 ', '004960'],
#        ['해성산업 ', '034810']], dtype=object)

# %%
import pandas as pd

df_list=[fdr.DataReader(code,'2019')['Close']for name, code in stock_list]
len(df_list)
# Out:
# 16

# %%
#pd.concat()로 합치기

df3=pd.concat(df_list,axis=1)
df3.columns=[name for name, code in stock_list]
df3
# Out:
#             DB금융투자   KPX홀딩스   SG&G   SK디스커버리    대덕   삼정펄프   성도이엔지   세원물산   \
# Date
# 2019-01-02     4320    61400   2330     25600  8933  33400    4910   5210
# 2019-01-03     4300    60600   2380     25000  9195  33350    4810   5180
# 2019-01-04     4360    60600   2495     24900  9275  33350    4870   5290
# 2019-01-07     4485    61000   2345     24650  9386  33450    4870   5290
# 2019-01-08     4460    61000   2285     24850  9305  33050    4845   5250
# ...             ...      ...    ...       ...   ...    ...     ...    ...
# 2022-03-03     6280    61100   2285     40850  7540  27650    5170   6280
# 2022-03-04     6270    60600   2325     39950  7460  27800    5200   6280
# 2022-03-07     6110    60200   2250     39000  7270  28200    5140   6280
# 2022-03-08     6020    59900   2200     38850  7170  27450    5190   6280
# 2022-03-10     6270    60100   2550     39250  7340  27650    5220   6280
#
#               원림    원익   유성티엔에스   유수홀딩스   이지홀딩스   한솔홀딩스   한신공영   해성산업
# ...

# %% [markdown]
# ## 종목간의 가격차이가 커서 서로 비교어려워서, secondary_y옵션을
# ## 활용하여 서로 다른 영역을 비교하기 용이

# %%
df3.plot(figsize=(14,13))
plt.title('Per&Pbr 상위 종목 3년 종가비교')
# Out:
# Text(0.5, 1.0, 'Per&Pbr 상위 종목 3년 종가비교')

# %% [markdown]
# ### 종목들이 서로 다른 행보를 가지는 거 처럼 보이지만 시작점이 다르기 때문에
#
# ### 시간에 따른 변화를 보기 쉽지 않기 때문에
# ### 시작점을 0으로 동일하기 맞추고 시간에 따른 수익률을 보기 위해
# ### 첫번째 행(row)으로 모든 행(row)을 나누고 1.0을 빼줌

# %%
df_plot=df3/df3.iloc[0] - 1.0
df_plot.plot(figsize=(14,13))
plt.title('Per&Pbr 상위 종목 3년 종가비교')
# Out:
# Text(0.5, 1.0, 'Per&Pbr 상위 종목 3년 종가비교')

# %%
df3=df_plot.plot(subplots=True,figsize=(14,13))
df3
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
# 전 종목 종가 빈도수 
import matplotlib.pyplot as plt
df_plot.hist(figsize=(14,12),bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'DB금융투자 '}>,
#         <AxesSubplot:title={'center':'KPX홀딩스 '}>,
#         <AxesSubplot:title={'center':'SG&G '}>,
#         <AxesSubplot:title={'center':'SK디스커버리 '}>],
#        [<AxesSubplot:title={'center':'대덕 '}>,
#         <AxesSubplot:title={'center':'삼정펄프 '}>,
#         <AxesSubplot:title={'center':'성도이엔지 '}>,
#         <AxesSubplot:title={'center':'세원물산 '}>],
#        [<AxesSubplot:title={'center':'원림 '}>,
#         <AxesSubplot:title={'center':'원익 '}>,
#         <AxesSubplot:title={'center':'유성티엔에스 '}>,
#         <AxesSubplot:title={'center':'유수홀딩스 '}>],
#        [<AxesSubplot:title={'center':'이지홀딩스 '}>,
#         <AxesSubplot:title={'center':'한솔홀딩스 '}>,
#         <AxesSubplot:title={'center':'한신공영 '}>,
#         <AxesSubplot:title={'center':'해성산업 '}>]], dtype=object)
